# %%
from pydantic import BaseModel,Field
from typing import List

class Quote(BaseModel):
    """Motivational quotes details"""
    quote:str=Field(...,description="Motivational quotes")
    hashtag:List[str]=Field(...,description="List of 7 hashtag for facebook related to quotes")

class QuoteList(BaseModel):
    """ Motivational , self help , Quotes list """
    quotes: List[Quote]

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")

# %%
### ChatOpenAI

from langchain_openai import ChatOpenAI
model=ChatOpenAI(model="gpt-4.1")
model_with_output = model.with_structured_output(QuoteList)

# %%
prompt = "You are motivation and self help content writer. You have to give me 100 motivation quotes which" \
"encourage and boost morales. and for each quotes you have to also provide best 7 hashtag for facebook posts content."
response=model_with_output.invoke(prompt)
# Out:
# QuoteList(quotes=[Quote(quote='Believe in yourself and all that you are. Know that there is something inside you that is greater than any obstacle.', hashtag=['#BelieveInYourself', '#SelfConfidence', '#Motivation', '#StayStrong', '#KeepPushing', '#Inspiration', '#OvercomeObstacles']), Quote(quote='Success is not final, failure is not fatal: it is the courage to continue that counts.', hashtag=['#SuccessMindset', '#NeverGiveUp', '#KeepGoing', '#MotivationalQuotes', '#Courage', '#Resilience', '#InspireDaily']), Quote(quote='Your only limit is your mind.', hashtag=['#MindsetMatters', '#NoLimits', '#ThinkBig', '#MentalStrength', '#UnlockPotential', '#DreamBig', '#Motivation']), Quote(quote='Every day is a new beginning. Take a deep breath, smile, and start again.', hashtag=['#NewBeginnings', '#FreshStart', '#StayPositive', '#SmileMore', '#Motivation', '#DailyInspiration', '#StartAgain']), Quote(quote='Push yourself, because no one else is going to do it for you.', hashtag=['#PushYourself', '#SelfMotivation', '#TakeAction', '#BeYourBest', '#MakeItHappen', '#PersonalGrowth', '#EmpowerYourself']), Quote(quote='Difficult roads often lead to beautiful destinations.', hashtag=['#KeepGoing', '#DifficultRoads', '#JourneyToSuccess', '#StayStrong', '#Motivation', '#BeautifulDestinations', '#NeverGiveUp']), Quote(quote='Don’t watch the clock; do what it does. Keep going.', hashtag=['#TimeManagement', '#KeepMoving', '#Motivation', '#Persistence', '#ActionTaker', '#InspiredLiving', '#StayProductive']), Quote(quote='You are capable of amazing things.', hashtag=['#BelieveInYou', '#AmazingThings', '#SelfBelief', '#Empowerment', '#Positivity', '#Inspiration', '#Motivation']), Quote(quote='Great things never come from comfort zones.', hashtag=['#NoComfortZone', '#ChaseGreatness', '#StepOut', '#GrowthMindset', '#ChallengeYourself', '#Success', '#Inspirational']), Quote(quote='It always seems impossible until it’s done.', hashtag=['#ImpossibleIsNothing', '#UntilItsDone', '#KeepTrying', '#Motivation', '#BelieveToAchieve', '#Inspiration', '#NeverGiveUp']), Quote(quote='Dream it. Wish it. Do it.', hashtag=['#DreamBig', '#TakeAction', '#WishItDoIt', '#Goals', '#Motivation', '#ActionSpeaks', '#InspireOthers']), Quote(quote='Don’t stop when you’re tired. Stop when you’re done.', hashtag=['#KeepPushing', '#FinishStrong', '#NeverQuit', '#Endurance', '#Motivation', '#StayDedicated', '#AchieveMore']), Quote(quote='Your future is created by what you do today, not tomorrow.', hashtag=['#ActNow', '#CreateFuture', '#DoItToday', '#Motivation', '#SeizeTheDay', '#Inspiration', '#SuccessHabits']), Quote(quote='Little things make big days.', hashtag=['#SmallSteps', '#BigResults', '#DailyMotivation', '#Consistency', '#MotivationalQuotes', '#LittleThings', '#SuccessTips']), Quote(quote='Doubt kills more dreams than failure ever will.', hashtag=['#NoDoubt', '#OvercomeFear', '#SelfBelief', '#DreamBig', '#FailureIsLesson', '#Motivation', '#ChaseYourDreams']), Quote(quote='Don’t limit your challenges. Challenge your limits.', hashtag=['#Limitless', '#PushYourLimits', '#ChallengeYourself', '#GrowBeyond', '#BreakBarriers', '#Motivation', '#Inspiration']), Quote(quote='Hard work beats talent when talent doesn’t work hard.', hashtag=['#HardWorkPays', '#TalentVsHardWork', '#WorkHard', '#StayDedicated', '#SuccessMindset', '#Motivation', '#Inspiration']), Quote(quote='Success doesn’t come from what you do occasionally, it comes from what you do consistently.', hashtag=['#ConsistencyIsKey', '#SuccessHabits', '#KeepGrinding', '#DailyRoutine', '#Motivation', '#GrowthMindset', '#StayConsistent']), Quote(quote='Stay positive, work hard, make it happen.', hashtag=['#StayPositive', '#WorkHard', '#MakeItHappen', '#Motivation', '#SuccessMindset', '#Inspiration', '#DreamBig']), Quote(quote='Opportunities don’t happen. You create them.', hashtag=['#CreateOpportunities', '#BeProactive', '#TakeInitiative', '#OpportunityKnocks', '#Motivation', '#SuccessTips', '#ActionTaker']), Quote(quote='You a ...

# %%
def splittext(sentence,wordCount):
    words = sentence.split()
    word_groups = [words[i:i+wordCount] for i in range(0, len(words), wordCount)]
    result_strings = [' '.join(group) for group in word_groups]
    return result_strings

# %%
COUNTER_FILE = '/mnt/c/edit/images/counter.txt'

def update_counter():
    """Reads the current counter value from a file, increments it, and writes the new value back."""
    with open(COUNTER_FILE, 'r') as f:
        count = int(f.read())
    count += 1
    with open(COUNTER_FILE, 'w') as f:
        f.write(str(count))
    return count

# %%
from PIL import Image, ImageDraw, ImageFont

def text_to_image(quote:Quote):
    # ---------- CONFIG ----------
    WIDTH, HEIGHT = 1080, 1920   # Story size
    BG_COLOR = (10, 10, 10)      # Dark grey background
    TEXT_COLOR = (255, 255, 255)

    TEXT = quote.quote
    TEXT = splittext(TEXT,3)
    SENT = "\n\n ".join(TEXT)

    # FONT_PATH = "seguiemj.ttf"   # Change if needed
    FONT_PATH = "Roboto.ttf"   # Change if needed
    FONT_SIZE = 100
    LINE_SPACING = 18
    # ----------------------------

    # Create image
    img = Image.new("RGB", (WIDTH, HEIGHT), BG_COLOR)
    draw = ImageDraw.Draw(img)

    # Load font
    font = ImageFont.truetype(FONT_PATH, FONT_SIZE)

    # Calculate text size
    bbox = draw.multiline_textbbox((0, 0), SENT, font=font, spacing=LINE_SPACING)
    text_width = bbox[2] - bbox[0]
    text_height = bbox[3] - bbox[1]

    # Center position
    x = (WIDTH - text_width) // 2
    y = (HEIGHT - text_height) // 2

    # Draw text
    draw.multiline_text(
        (x, y),
        SENT,
        fill=TEXT_COLOR,
        font=font,
        align="center",
        spacing=LINE_SPACING
    )
    file_no = update_counter();
    # Save image
    hashtags =" ".join(quote.hashtag)  

    file_name = f"/mnt/c/edit/images/quotes_{file_no}" 
    image_file_name = file_name+".png"
    hashtag_file_name = file_name+".txt"

    img.save(file_name+".png", quality=95)
    with open(hashtag_file_name, 'w') as file:
        file.write(hashtags)

    print("Image generated: ",file_name)

# %%
quotes = response
for q in quotes.quotes:
    text_to_image(q)
# Out:
# Image generated:  /mnt/c/edit/images/quotes_11
# Image generated:  /mnt/c/edit/images/quotes_12
# Image generated:  /mnt/c/edit/images/quotes_13
# Image generated:  /mnt/c/edit/images/quotes_14
# Image generated:  /mnt/c/edit/images/quotes_15
# Image generated:  /mnt/c/edit/images/quotes_16
# Image generated:  /mnt/c/edit/images/quotes_17
# Image generated:  /mnt/c/edit/images/quotes_18
# Image generated:  /mnt/c/edit/images/quotes_19
# Image generated:  /mnt/c/edit/images/quotes_20
# Image generated:  /mnt/c/edit/images/quotes_21
# Image generated:  /mnt/c/edit/images/quotes_22
# Image generated:  /mnt/c/edit/images/quotes_23
# Image generated:  /mnt/c/edit/images/quotes_24
# Image generated:  /mnt/c/edit/images/quotes_25
# Image generated:  /mnt/c/edit/images/quotes_26
# Image generated:  /mnt/c/edit/images/quotes_27
# Image generated:  /mnt/c/edit/images/quotes_28
# Image generated:  /mnt/c/edit/images/quotes_29
# Image generated:  /mnt/c/edit/images/quotes_30
# Image generated:  /mnt/c/edit/images/quotes_31
# Image generated:  /mnt/c/edit/images/quotes_32
# Image generated:  /mnt/c/edit/images/quotes_33
# Image generated:  /mnt/c/edit/images/quotes_34
# Image generated:  /mnt/c/edit/images/quotes_35
# Image generated:  /mnt/c/edit/images/quotes_36
# Image generated:  /mnt/c/edit/images/quotes_37
# Image generated:  /mnt/c/edit/images/quotes_38
# Image generated:  /mnt/c/edit/images/quotes_39
# Image generated:  /mnt/c/edit/images/quotes_40
# Image generated:  /mnt/c/edit/images/quotes_41
# Image generated:  /mnt/c/edit/images/quotes_42
# Image generated:  /mnt/c/edit/images/quotes_43
# Image generated:  /mnt/c/edit/images/quotes_44
# Image generated:  /mnt/c/edit/images/quotes_45
# Image generated:  /mnt/c/edit/images/quotes_46
# Image generated:  /mnt/c/edit/images/quotes_47
# Image generated:  /mnt/c/edit/images/quotes_48
# Image generated:  /mnt/c/edit/images/quotes_49
# Image generated:  /mnt/c/edit/images/quotes_50
# Image generated:  /mnt/c/edit/images/quotes_51
# Image generated:  /mnt/c/edit/images/quotes_52
# Image generated:  /mnt/c/edit/images/quotes_53
# Image generated:  /mnt/c/edit/images/quotes_54
# Image generated:  /mnt/c/edit/images/quotes_55
# Image generated:  /mnt/c/edit/images/quotes_56
# Image generated:  /mnt/c/edit/images/quotes_57
# Image generated:  /mnt/c/edit/images/quotes_58
# Image generated:  /mnt/c/edit/images/quotes_59
# Image generated:  /mnt/c/edit/images/quotes_60
# Image generated:  /mnt/c/edit/images/quotes_61
# Image generated:  /mnt/c/edit/images/quotes_62
# Image generated:  /mnt/c/edit/images/quotes_63
# Image generated:  /mnt/c/edit/images/quotes_64
# Image generated:  /mnt/c/edit/images/quotes_65
# Image generated:  /mnt/c/edit/images/quotes_66
# Image generated:  /mnt/c/edit/images/quotes_67
# Image generated:  /mnt/c/edit/images/quotes_68
# Image generated:  /mnt/c/edit/images/quotes_69
# Image generated:  /mnt/c/edit/images/quotes_70
# Image generated:  /mnt/c/edit/images/quotes_71
# Image generated:  /mnt/c/edit/images/quotes_72
# Image generated:  /mnt/c/edit/images/quotes_73
# Image generated:  /mnt/c/edit/images/quotes_74
# Image generated:  /mnt/c/edit/images/quotes_75
# Image generated:  /mnt/c/edit/images/quotes_76
# Image generated:  /mnt/c/edit/images/quotes_77
# Image generated:  /mnt/c/edit/images/quotes_78
# Image generated:  /mnt/c/edit/images/quotes_79
# Image generated:  /mnt/c/edit/images/quotes_80
# Image generated:  /mnt/c/edit/images/quotes_81
# Image generated:  /mnt/c/edit/images/quotes_82
# Image generated:  /mnt/c/edit/images/quotes_83
# Image generated:  /mnt/c/edit/images/quotes_84
# Image generated:  /mnt/c/edit/images/quotes_85
# Image generated:  /mnt/c/edit/images/quotes_86
# Image generated:  /mnt/c/edit/images/quotes_87
# Image generated:  /mnt/c/edit/images/quotes_88
# Image generated:  /mnt/c/edit/images/quotes_89
# Image generated:  /mnt/c/edit/images/quotes_90
# Image generated:  /mnt/c/edit/images/quotes_91
# Image generated:  /mnt/c/edit/images/quotes_92
# Image generated:  /mnt/c/edit/images/quotes_93
# Image generated:  /mnt/c/edit/images/quotes_94
# Image generated:  /mnt/c/edit/images/quotes_95
# Image generated:  /mnt/c/edit/images/quotes_96
# Image generated:  /mnt/c/edit/images/quotes_97
# Image generated:  /mnt/c/edit/images/quotes_98
# Image generated:  /mnt/c/edit/images/quotes_99
# Image generated:  /mnt/c/edit/images/quotes_100
# Image generated:  /mnt/c/edit/images/quotes_101
# Image generated:  /mnt/c/edit/images/quotes_102
# Image generated:  /mnt/c/edit/images/quotes_103
# Image generated:  /mnt/c/edit/images/quotes_104
# Image generated:  /mnt/c/edit/images/quotes_105
# Image generated:  /mnt/c/edit/images/quotes_106
# Image generated:  /mnt/c/edit/images/quotes_107
# Image generated:  /mnt/c/edit/images/quotes_108
# Image generated:  /mnt/c/edit/images/quotes_109
# Image generated:  /mnt/c/edit/images/quotes_110
# Image generated:  /mnt/c/edit/images/quotes_111
# Image generated:  /mnt/c/edit/images/quotes_112
# Image generated:  /mnt/c/edit/images/quotes_113
# Image generated:  /mnt/c/edit/images/quotes_114
# Image generated:  /mnt/c/edit/images/quotes_115
# Image generated:  /mnt/c/edit/images/quotes_116
# Image generated:  /mnt/c/edit/images/quotes_117

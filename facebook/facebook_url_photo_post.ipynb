# %%
from typing import List
from pathlib import Path
from pydantic import TypeAdapter, BaseModel
from typing import Dict
import json
import os
from dotenv import load_dotenv
load_dotenv() 
import requests

class Page(BaseModel):
    id: str
    name: str
    access_token: str

class UserAccount(BaseModel):
    id: str
    name: str
    access_token: str
    pages: List[Page]

# %%
file_path = '//home//maniram//workspace//data//fb.json'
raw_data = "{}"

try:
    with open(file_path, 'r') as file:
        raw_data = json.load(file)
except FileNotFoundError:
    print(f"Error: The file '{file_path}' was not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# %%
# Define the adapter for a Dict with Page objects as values
adapter = TypeAdapter(Dict[str, UserAccount])

# Convert the raw dictionary into a dictionary of Page objects
pages_dict = adapter.validate_python(raw_data)

# %%
pages_dict['mw'].pages[0].id
# Out:
# '528528303685416'

# %%
import time

current_unix_time_int = int(time.time())
print(current_unix_time_int)
# Out:
# 1768928484

# %%
SCHEDULED_TIME=current_unix_time_int+(24*3600)
PAGE_ID=pages_dict['mw'].pages[0].id
ACCESS_TOKEN=pages_dict['mw'].pages[0].access_token

# Replace with your actual Page ID and Access Token
# MESSAGE = "Don't let yesterday take up too much of today."
MESSAGE = ""
HASHTAG = "\n.\n.\n.\n. #dailymotivation #motivationalquotes #Motivation #Success #Inspiration #Mindset #DreamBig #StayFocused #KeepGoing #BelieveInYourself #HardWorkPaysOff #NeverGiveUp #PositiveVibes #GoalGetter #SelfDiscipline #GrowthMindset #YouGotThis"
# The Graph API endpoint for posting to a page's feed
url = f"https://graph.facebook.com/v24.0/{PAGE_ID}/feed" # Use a current API version

# The payload (data) to be sent in the POST request
params = {
    "access_token":ACCESS_TOKEN
}
payload = {
    'message': MESSAGE+HASHTAG,
    'published':"true",
    # "scheduled_publish_time":f"{SCHEDULED_TIME}",
    "link":"https://oaidalleapiprodscus.blob.core.windows.net/private/org-Pui4NOlkNBHdgO8H0JbCpbaR/user-3IbAuW2Ta716U78aWFKyb8zc/img-BTfC3lYdyfu1oGSDUeq8zZB5.png?st=2026-01-20T15%3A35%3A42Z&se=2026-01-20T17%3A35%3A42Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=7aed557a-269d-4dda-ab8b-c66e34024151&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2026-01-20T16%3A05%3A21Z&ske=2026-01-21T16%3A05%3A21Z&sks=b&skv=2024-08-04&sig=Qsm7G3FSJXgDpFbzYmpv9Dbnj56HfipdMis2TbtbHY8%3D",
}
response_data = ""
try:
    # Send the POST request to the Facebook Graph API
    response = requests.post(url,params=params, data=payload)
    response_data = response.json()

    # Check the response status
    if response.status_code == 200:
        print("Post successful!")
        print(f"Post ID: {response_data['id']}")
    else:
        print("Failed to post.")
        print(f"Error details: {response_data}")

except requests.exceptions.RequestException as e:
    print(f"An error occurred during the request: {e}")

response_data
# Out:
# Post successful!
# Post ID: 528528303685416_122170048298781957
# {'id': '528528303685416_122170048298781957'}
